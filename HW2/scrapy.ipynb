# %%
import requests
from bs4 import BeautifulSoup
import urllib3

urllib3.disable_warnings()
rs = requests.session()
def get_hrefs_from_page(url,y,rs=rs):
    html = rs.get(url)
    soup = BeautifulSoup(html.text,'lxml')
    jud = soup.select('div td .hlTitle_scroll')
    for j in jud:
        jud_url = 'https://law.judicial.gov.tw/FJUD/' + j['href']
        write_data(jud_url,j.text,y)  
    next_page_url = soup.select_one('div span #hlNext')['href'] 
    next_page_url = 'https://law.judicial.gov.tw' + next_page_url
    try:
        get_hrefs_from_page(next_page_url,y)
    except:
        print('end of track')
    
def write_data(url,title,y,rs=rs):
    
    html = rs.get(url)
    soup = BeautifulSoup(html.text,'lxml')
    jud_data = soup.select('div #jud')[0].text
    with open('C:/Users/HARRY/Desktop/judfile3/jud{}/{}.txt'.format(y,title),'w',encoding='utf-8') as w:
        try:
            w.write(jud_data)
        except:
            w.write(jud_data.encode('utf8').decode('cp950','ignore'))

        
def Scrapy_jud_by_time(y,m1,m2,rs = rs):
    print(y,m1,m2)
    payload = {'__VIEWSTATE': 'Pk+gKf6PVHLN6kIcpfkcPC67q2n68hRxxOCNiUo+tE6sVgWqWJBRsr2608CIOgSUU1r16zyJD9gHCvufnH2Baqlv51+jxHAkyukHsD0F5c5r0Nd+6szmcoXrZbCF0jJTbuKAsaRSKy2s7vH4uUDvdFyW18zb9I6+sUddXg==',
               '__VIEWSTATEGENERATOR': '1BCFD4C6',
               '__VIEWSTATEENCRYPTED':'' ,
               '__EVENTVALIDATION': 'wLy31Mjm6nK1/0RQ6gMif3ujujaVMrwOfhyaEqVVkgOTGUP/RpEkPbxKPkReq8gQsft+qffeDOn4hho5l9dlwcWJvaI=',
               'jud_court':'' ,
               'jud_sys': 'V',
            'jud_year': '',
            'sel_judword':'', 
            'jud_case':'', 
            'jud_no':'' ,
            'jud_no_end':'', 
            'dy1': '{}'.format(y),
            'dm1': '{}'.format(m1),
            'dd1': '01',
            'dy2': '{}'.format(y),
            'dm2': '{}'.format(m2),
            'dd2': '31',
            'jud_title':'' ,
            'jud_jmain': '',
            'jud_kw': '民法第1052條',
            'judtype': 'JUDBOOK',
            'whosub': '1',
            'ctl00$cp_content$btnQry': '送出查詢'}
#     rs = requests.session()

    html = rs.post("https://law.judicial.gov.tw/FJUD/default_AD.aspx",data = payload,verify = False)
#     print(html.text)
    soup = BeautifulSoup(html.text,'lxml')
    connect = soup.select(".main-section > iframe")[0]['src']
    url = 'https://law.judicial.gov.tw/FJUD/' + str(connect)        
    get_hrefs_from_page(url,y)
    
if __name__ == "__main__":
    rs = requests.session()
    y_list = list();m_list = list();
    y_list = ['108','107','106']
    m_list = ['01','02','03','04','05','06','07','08','09','10','11','12']
    for y in y_list:
        if y == '108':
            for m in range(0,4,3):  
                Scrapy_jud_by_time(y,m_list[m],m_list[m+2])  
        else:
            for m in range(0,10,3):  
                Scrapy_jud_by_time(y,m_list[m],m_list[m+2])
# Out:
# 108 01 03
# end of track
# 108 04 06
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5d0c540d825e> in <module>()
#      73         if y == '108':
#      74             for m in range(0,4,3):
# ---> 75                 Scrapy_jud_by_time(y,m_list[m],m_list[m+2])
#      76         else:
#      77             for m in range(0,10,3):
#
# <ipython-input-10-5d0c540d825e> in Scrapy_jud_by_time(y, m1, m2, rs)
#      63     connect = soup.select(".main-section > iframe")[0]['src']
#      64     url = 'https://law.judicial.gov.tw/FJUD/' + str(connect)
# ---> 65     get_hrefs_from_page(url,y)
#      66
#      67 if __name__ == "__main__":
#
# <ipython-input-10-5d0c540d825e> in get_hrefs_from_page(url, y, rs)
#      11     for j in jud:
#      12         jud_url = 'https://law.judicial.gov.tw/FJUD/' + j['href']
# ---> 13         write_data(jud_url,j.text,y)
#      14     next_page_url = soup.select_one('div span #hlNext')['href']
#      15     next_page_url = 'https://law.judicial.gov.tw' + next_page_url
#
# <ipython-input-10-5d0c540d825e> in write_data(url, title, y, rs)
#      21 def write_data(url,title,y,rs=rs):
#      22
# ---> 23     html = rs.get(url)
#      24     soup = BeautifulSoup(html.text,'lxml')
#      25     jud_data = soup.select('div #jud')[0].text
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# c:\users\harry\appdata\local\programs\python\python36\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# c:\users\harry\appdata\local\programs\python\python36\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\users\harry\appdata\local\programs\python\python36\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\users\harry\appdata\local\programs\python\python36\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# c:\users\harry\appdata\local\programs\python\python36\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import urllib3

urllib3.disable_warnings()
rs = requests.session()
def get_hrefs_from_page(url,y,rs=rs):
    html = rs.get(url)
    soup = BeautifulSoup(html.text,'lxml')
    jud = soup.select('div td .hlTitle_scroll')
    for j in jud:
        jud_url = 'https://law.judicial.gov.tw/FJUD/' + j['href']
        write_data(jud_url,j.text,y)
#     print(html.text)
    try:
        next_page_url = soup.select_one('div span #hlNext')['href'] 
        next_page_url = 'https://law.judicial.gov.tw' + next_page_url
#    try:
        get_hrefs_from_page(next_page_url,y)
    except:
        print('end of track')
    
def write_data(url,title,y,rs=rs):
    
    html = rs.get(url)
    soup = BeautifulSoup(html.text,'lxml')
    jud_data = soup.select('div #jud')[0].text
    with open('C:/Users/HARRY/Desktop/judfiles1052/judfileten-1-10/jud{}/{}.txt'.format(y,title),'w',encoding='utf-8') as w:
#         pass
        try:
            w.write(jud_data)
        except:
            w.write(jud_data.encode('utf8').decode('cp950','ignore'))

        
def Scrapy_jud_by_time(y,m1,m2,rs = rs):
    print(y,m1,m2)
    payload = {'__VIEWSTATE': 'N3fFhsqgHd0Sc2gaoTlLsrSJ9aEEKoysVptxdtr8zLKjvp2M/jCR5RCSmpXJ89MPjF7+mjJDsmX5J22XVPNO5RwJViAqekSnf6oMKQgeqJq5gLef8MC1eMkXZD/cdNVq9Kofz9QK43fWbOiipmm0jC/22repThRVTAhQrLhvBDThSUUfigaGFXqhp6djdofd4Kxm+ktpqFUdQFDI',
               '__VIEWSTATEGENERATOR': 'CCE6FCB1',
               '__VIEWSTATEENCRYPTED':'' ,
               '__EVENTVALIDATION': '9dHMXs6PjqxeOaVFORh+4Z83tyIDGL4XtlQaIAiMe5T+IsyUgx+7aaud7cwEk7u76dHZ8Qf7pqw65xuhwBWloEoN24c=',
#                'jud_court':'' ,
               'jud_court': 'TPD,SLD,PCD,ILD,KLD,TYD,SCD,MLD,TCD,CHD,NTD,ULD,CYD,TND,KSD,CTD,HLD,TTD,PTD,PHD,KMD,LCD',
               'jud_sys': 'V',
            'jud_year': '',
            'sel_judword':'', 
            'jud_case':'', 
            'jud_no':'' ,
            'jud_no_end':'', 
            'dy1': '{}'.format(y),
            'dm1': '{}'.format(m1),
            'dd1': '01',
            'dy2': '{}'.format(y),
            'dm2': '{}'.format(m2),
            'dd2': '31',
            'jud_title':'' ,
            'jud_jmain': '',
            'jud_kw': '民法第1052條第1項第10',
            'judtype': 'JUDBOOK',
            'whosub': '0',
            'ctl00$cp_content$btnQry': '送出查詢'}
#     rs = requests.session()

    html = rs.post("https://law.judicial.gov.tw/FJUD/default_accfree.aspx",data = payload,verify = False)
#     print(html.text)
    soup = BeautifulSoup(html.text,'lxml')
    connect = soup.select(".main-section > iframe")[0]['src']
    url = 'https://law.judicial.gov.tw/FJUD/' + str(connect)
#     print(html.text)
#     print(connect)
    get_hrefs_from_page(url,y)
    
if __name__ == "__main__":
    rs = requests.session()
    y_list = list();m_list = list();
    y_list = ['108','107','106','105','104','103','102','101','100']
#     y_list = ['101','100']
    m_list = ['01','02','03','04','05','06','07','08','09','10','11','12']
    for y in y_list:
        if y == '108':
            for m in range(0,5,2):  
                Scrapy_jud_by_time(y,m_list[m],m_list[m+1])  
        else:
            for m in range(0,11,2):  
                Scrapy_jud_by_time(y,m_list[m],m_list[m+1])
# Out:
# 108 01 02
# end of track
# 108 03 04
# end of track
# 108 05 06
# end of track
# 107 01 02
# end of track
# 107 03 04
# end of track
# 107 05 06
# end of track
# 107 07 08
# end of track
# 107 09 10
# end of track
# 107 11 12
# end of track
# 106 01 02
# end of track
# 106 03 04
# end of track
# 106 05 06
# end of track
# 106 07 08
# end of track
# 106 09 10
# end of track
# 106 11 12
# end of track
# 105 01 02
# end of track
# 105 03 04
# end of track
# 105 05 06
# end of track
# 105 07 08
# end of track
# 105 09 10
# end of track
# 105 11 12
# end of track
# 104 01 02
# end of track
# 104 03 04
# end of track
# 104 05 06
# end of track
# 104 07 08
# end of track
# 104 09 10
# end of track
# 104 11 12
# end of track
# 103 01 02
# end of track
# 103 03 04
# end of track
# 103 05 06
# end of track
# 103 07 08
# end of track
# 103 09 10
# end of track
# 103 11 12
# end of track
# 102 01 02
# end of track
# 102 03 04
# end of track
# 102 05 06
# end of track
# 102 07 08
# end of track
# 102 09 10
# end of track
# 102 11 12
# end of track
# 101 01 02
# end of track
# 101 03 04
# end of track
# 101 05 06
# end of track
# 101 07 08
# end of track
# 101 09 10
# end of track
# 101 11 12
# end of track
# 100 01 02
# end of track
# 100 03 04
# end of track
# 100 05 06
# end of track
# 100 07 08
# end of track
# 100 09 10
# end of track
# 100 11 12
# end of track
